# %% [markdown]
# # Pattern Recognition Assignment 1
#
# **Index No:** 210210G
# **Name:** Hasaranga T.N.
#
# ---
#
# ## 1. Import Required Libraries
# Import necessary Python libraries for calculations and data handling.

# %%
# Import Required Libraries
import numpy as np
import pandas as pd

# %% [markdown]
# ## 2. Display Notebook Index and Name
# Set your index number and name as variables and display them below.

# %%
# Set index and name
index_no = "210210G"
name = "Hasaranga T.N."
print(f"Index No: {index_no}")
print(f"Name: {name}")

# %% [markdown]
# ## 3. Perform Sample Calculation
# Below is a demonstration of a simple calculation using Python.

# %%
# Sample calculation: Add two numbers
num1 = 7
num2 = 5
sum_result = num1 + num2
print(f"Sum of {num1} and {num2} is {sum_result}")

# Create a numpy array
data = np.array([1, 2, 3, 4, 5])
print("Numpy array:", data)
